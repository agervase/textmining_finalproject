# %% [markdown]
# # NLTK corpus reader

# %%
# Imports
import os
from   nltk.corpus.reader import PlaintextCorpusReader

# Where are the corpus texts on your system
text_dir = os.path.join('..', 'data', 'texts')

# Regex to identify text files
text_pattern = '.+\.txt'

# Initialize the corpus reader
plain_corpus = PlaintextCorpusReader(text_dir, text_pattern)

# %%
plain_corpus.fileids()
# Out:
# ['prompt000_000_4045.txt',
#  'prompt000_001_9856.txt',
#  'prompt000_002_228.txt',
#  'prompt000_003_126.txt',
#  'prompt000_004_101.txt',
#  'prompt000_005_23.txt',
#  'prompt000_006_21.txt',
#  'prompt000_007_25.txt',
#  'prompt000_008_9.txt',
#  'prompt000_009_10.txt',
#  'prompt000_010_9.txt',
#  'prompt000_011_7.txt',
#  'prompt000_012_10.txt',
#  'prompt000_013_5.txt',
#  'prompt000_014_6.txt',
#  'prompt000_015_4.txt',
#  'prompt000_016_4.txt',
#  'prompt000_017_3.txt',
#  'prompt000_018_3.txt',
#  'prompt000_019_3.txt',
#  'prompt000_020_2.txt',
#  'prompt000_021_2.txt',
#  'prompt000_022_2.txt',
#  'prompt000_023_2.txt',
#  'prompt000_024_2.txt',
#  'prompt000_025_3.txt',
#  'prompt000_026_1.txt',
#  'prompt001_000_5075.txt',
#  'prompt001_001_268.txt',
#  'prompt001_002_55.txt',
#  'prompt001_003_34.txt',
#  'prompt001_004_17.txt',
#  'prompt001_005_6.txt',
#  'prompt001_006_12.txt',
#  'prompt001_007_2.txt',
#  'prompt001_008_0.txt',
#  'prompt002_000_4831.txt',
#  'prompt002_001_700.txt',
#  'prompt002_002_154.txt',
#  'prompt002_003_47.txt',
#  'prompt002_004_15.txt',
#  'prompt002_005_18.txt',
#  'prompt002_006_11.txt',
#  'prompt002_007_27.txt',
#  'prompt002_008_4.txt',
#  'prompt002_009_4.txt',
#  'prompt002_010_5.txt',
#  'prompt002_011_2.txt',
#  'prompt002_012_2.txt',
#  'prompt003_000_2358.txt',
#  'prompt003_001_248.txt',
#  'prompt003_002_4645.txt',
#  'prompt003_003_160.txt',
#  'prompt003_004_1188.txt',
#  'prompt003_005_88.txt',
#  'prompt003_006_32.txt',
#  'prompt003_007_18.txt',
#  'prompt003_008_41.txt',
#  'prompt003_009_9.txt',
#  'prompt003_010_8.txt',
#  'prompt003_011_4.txt',
#  'prompt003_012_4.txt',
#  'prompt003_013_3.txt',
#  'prompt003_014_7.txt',
#  'prompt003_015_3.txt',
#  'prompt003_016_3.txt',
#  'prompt003_017_3.txt',
#  'prompt003_018_2.txt',
#  'prompt003_019_2.txt',
#  'prompt003_020_4.txt',
#  'prompt003_021_2.txt',
#  'prompt003_022_1.txt',
#  'prompt003_023_1.txt',
#  'prompt003_024_1.txt',
#  'prompt003_025_1.txt',
#  'prompt003_026_1.txt',
#  'prompt003_027_1.txt',
#  'prompt003_028_1.txt',
#  'prompt003_029_1.txt',
#  'prompt003_030_1.txt',
#  'prompt003_031_1.txt',
#  'prompt003_032_1.txt',
#  'prompt003_033_1.txt',
#  'prompt003_034_-1.txt',
#  'prompt004_000_16329.txt',
#  'prompt004_001_202.txt',
#  'prompt004_002_2526.txt',
#  'prompt004_003_410.txt',
#  'prompt004_004_32.txt',
#  'prompt004_005_7.txt',
#  'prompt004_006_3.txt',
#  'prompt005_000_1405.txt',
#  'prompt005_001_508.txt',
#  'prompt005_002_25203.txt',
#  'prompt005_003_4372.txt',
#  'prompt005_004_415.txt',
#  'prompt005_005_58.txt',
#  'prompt005_006_761.txt',
#  'prompt005_007_320.txt',
#  'prompt005_008_323.txt',
#  'prompt005_009_39.txt',
#  'prompt005_010_42.txt',
#  'prompt005_011_16.txt',
#  'prompt005_012_14.txt',
#  'prompt005_013_42.txt',
#  'prompt005_014_10.txt',
#  'prompt005_015_8.txt',
#  'prompt005_016_15.txt',
#  'prompt005_017_6.txt',
#  'prompt005_018_7.txt',
#  'prompt005_019_5.txt',
#  'prompt005_020_6.txt',
#  'prompt005_021_5.txt',
#  'prompt005_022_5.txt',
#  'prompt005_023_5.txt',
#  'prompt005_024_5.txt',
#  'prompt005_025_3.txt',
#  'prompt005_026_3.txt',
#  'prompt005_027_3.txt',
#  'prompt005_028_3.txt',
#  'prompt005_029_3.txt',
#  'prompt005_030_3.txt',
#  'prompt005_031_4.txt',
#  'prompt005_032_2.txt',
#  'prompt005_033_2.txt',
#  'prompt006_000_4868.txt',
#  'prompt006_001_239.txt',
#  'prompt006_002_1149.txt',
#  'prompt006_003_536.txt',
#  'prompt006_004_78.txt',
#  'prompt006_005_302.txt',
#  'prompt006_006_54.txt',
#  'prompt006_007_17.txt',
#  'prompt006_008_16.txt',
#  'prompt006_009_11.txt',
#  'prompt006_010_5.txt',
#  'prompt006_011_6.txt',
#  'prompt006_012_3.txt',
#  'prompt006_013_1.txt',
#  'prompt007_000_7433.txt',
#  'prompt007_001_405.txt',
#  'prompt007_002_358.txt',
#  'prompt007_003_56.txt',
#  'prompt007_004_24.txt',
#  'prompt007_005_17.txt',
#  'prompt007_006_13.txt',
#  'prompt007_007_34.txt',
#  'prompt007_008_28.txt',
#  'prompt007_009_16.txt',
#  'prompt007_010_5.txt',
#  'prompt007_011_8.txt',
#  'prompt007_012_3.txt',
#  'prompt007_013_4.txt',
#  'prompt007_014_3.txt',
#  'prompt007_015_3.txt',
#  'prompt007_016_3.txt',
#  'prompt007_017_3.txt',
#  'prompt007_018_3.txt',
#  'prompt007_019_3.txt',
#  'prompt007_020_2.txt',
#  'prompt007_021_2.txt',
#  'prompt007_022_2.txt',
#  'prompt007_023_2.txt',
#  'prompt007_024_2.txt',
#  'prompt007_025_2.txt',
#  'prompt007_026_1.txt',
#  'prompt007_027_1.txt',
#  'prompt007_028_1.txt',
#  'prompt007_029_1.txt',
#  'prompt007_030_1.txt',
#  'prompt007_031_1.txt',
#  'prompt007_032_1.txt',
#  'prompt008_000_8132.txt',
#  'prompt008_001_398.txt',
#  'prompt008_002_1505.txt',
#  'prompt008_003_124.txt',
#  'prompt008_004_514.txt',
#  'prompt008_005_441.txt',
#  'prompt008_006_61.txt',
#  'prompt008_007_219.txt',
#  'prompt008_008_47.txt',
#  'prompt008_009_35.txt',
#  'prompt008_010_23.txt',
#  'prompt008_011_46.txt',
#  'prompt008_012_66.txt',
#  'prompt008_013_13.txt',
#  'prompt008_014_13.txt',
#  'prompt008_015_10.txt',
#  'prompt008_016_5.txt',
#  'prompt008_017_3.txt',
#  'prompt008_018_3.txt',
#  'prompt008_019_3.txt',
#  'prompt008_020_2.txt',
#  'prompt008_021_1.txt',
#  'prompt008_022_1.txt',
#  'prompt008_023_-1.txt',
#  'prompt009_000_2123.txt',
#  'prompt009_001_959.txt',
#  'prompt009_002_190.txt',
#  'prompt009_003_35.txt',
#  'prompt009_004_14.txt',
#  'prompt009_005_4.txt',
#  'prompt009_006_6.txt',
#  'prompt009_007_3.txt',
#  'prompt009_008_2.txt',
#  'prompt009_009_2.txt',
#  'prompt009_010_2.txt',
#  'prompt009_011_2.txt',
#  'prompt010_000_11707.txt',
#  'prompt010_001_103.txt',
#  'prompt010_002_565.txt',
#  'prompt010_003_1078.txt',
#  'prompt010_004_169.txt',
#  'prompt010_005_24.txt',
#  'prompt010_006_28.txt',
#  'prompt010_007_660.txt',
#  'prompt010_008_43.txt',
#  'prompt010_009_60.txt',
#  'prompt010_010_15.txt',
#  'prompt010_011_12.txt',
#  'prompt010_012_170.txt',
#  'prompt010_013_10.txt',
#  'prompt010_014_9.txt',
#  'prompt010_015_9.txt',
#  'prompt010_016_27.txt',
#  'prompt010_017_13.txt',
#  'prompt010_018_5.txt',
#  'prompt010_019_5.txt',
#  'prompt010_020_5.txt',
#  'prompt010_021_5.txt',
#  'prompt010_022_4.txt',
#  'prompt011_000_3936.txt',
#  'prompt011_001_67.txt',
#  'prompt011_002_126.txt',
#  'prompt011_003_295.txt',
#  'prompt011_004_47.txt',
#  'prompt011_005_29.txt',
#  'prompt011_006_5.txt',
#  'prompt011_007_3.txt',
#  'prompt011_008_2.txt',
#  'prompt011_009_2.txt',
#  'prompt011_010_1.txt',
#  'prompt012_000_5947.txt',
#  'prompt012_001_327.txt',
#  'prompt012_002_93.txt',
#  'prompt012_003_9.txt',
#  'prompt012_004_3.txt',
#  'prompt013_000_19613.txt',
#  'prompt013_001_1507.txt',
#  'prompt013_002_320.txt',
#  'prompt013_003_225.txt',
#  'prompt013_004_43.txt',
#  'prompt013_005_219.txt',
#  'prompt013_006_228.txt',
#  'prompt013_007_35.txt',
#  'prompt013_008_22.txt',
#  'prompt013_009_46.txt',
#  'prompt013_010_65.txt',
#  'prompt013_011_129.txt',
#  'prompt013_012_18.txt',
#  'prompt013_013_21.txt',
#  'prompt013_014_16.txt',
#  'prompt013_015_16.txt',
#  'prompt013_016_15.txt',
#  'prompt013_017_12.txt',
#  'prompt013_018_11.txt',
#  'prompt013_019_26.txt',
#  'prompt013_020_9.txt',
#  'prompt013_021_7.txt',
#  'prompt013_022_5.txt',
#  'prompt013_023_5.txt',
#  'prompt013_024_6.txt',
#  'prompt013_025_5.txt',
#  'prompt013_026_5.txt',
#  'prompt013_027_9.txt',
#  'prompt013_028_4.txt',
#  'prompt013_029_13.txt',
#  'prompt013_030_3.txt',
#  'prompt013_031_3.txt',
#  'prompt013_032_2.txt',
#  'prompt014_000_539.txt',
#  'prompt014_001_369.txt',
#  'prompt014_002_78.txt',
#  'prompt014_003_825.txt',
#  'prompt014_004_246.txt',
#  'prompt014_005_39.txt',
#  'prompt014_006_162.txt',
#  'prompt014_007_1670.txt',
#  'prompt014_008_3299.txt',
#  'prompt014_009_53.txt',
#  'prompt014_010_280.txt',
#  'prompt014_011_34.txt',
#  'prompt014_012_12.txt',
#  'prompt014_013_11.txt',
#  'prompt014_014_11.txt',
#  'prompt014_015_218.txt',
#  'prompt014_016_12.txt',
#  'prompt014_017_32.txt',
#  'prompt014_018_6.txt',
#  'prompt014_019_21.txt',
#  'prompt014_020_7.txt',
#  'prompt014_021_8.txt',
#  'prompt014_022_3.txt',
#  'prompt014_023_4.txt',
#  'prompt014_024_4.txt',
#  'prompt014_025_2.txt',
#  'prompt014_026_2.txt',
#  'prompt014_027_2.txt',
#  'prompt014_028_2.txt',
#  'prompt014_029_6.txt',
#  'prompt014_030_3.txt',
#  'prompt015_000_1366.txt',
#  'prompt015_001_4347.txt',
#  'prompt015_002_127.txt',
#  'prompt015_003_120.txt',
#  'prompt015_004_269.txt',
#  'prompt015_005_67.txt',
#  'prompt015_006_20.txt',
#  'prompt015_007_16.txt',
#  'prompt015_008_25.txt',
#  'prompt015_009_7.txt',
#  'prompt015_010_4.txt',
#  'prompt015_011_3.txt',
#  'prompt015_012_2.txt',
#  'prompt015_013_2.txt',
#  'prompt015_014_1.txt',
#  'prompt015_015_1.txt',
#  'prompt016_000_3396.txt',
#  'prompt016_001_1154.txt',
#  'prompt016_002_42.txt',
#  'prompt016_003_29.txt',
#  'prompt016_004_93.txt',
#  'prompt016_005_18.txt',
#  'prompt016_006_56.txt',
#  'prompt016_007_17.txt',
#  'prompt016_008_8.txt',
#  'prompt016_009_3.txt',
#  'prompt016_010_2.txt',
#  'prompt016_011_2.txt',
#  'prompt016_012_2.txt',
#  'prompt016_013_1.txt',
#  'prompt016_014_0.txt',
#  'prompt016_015_0.txt',
#  'prompt017_000_1894.txt',
#  'prompt017_001_4580.txt',
#  'prompt017_002_18.txt',
#  'prompt017_003_88.txt',
#  'prompt017_004_11.txt',
#  'prompt017_005_47.txt',
#  'prompt017_006_3.txt',
#  'prompt017_007_5.txt',
#  'prompt017_008_3.txt',
#  'prompt017_009_-2.txt',
#  'prompt018_000_6471.txt',
#  'prompt018_001_931.txt',
#  'prompt018_002_4235.txt',
#  'prompt018_003_157.txt',
#  'prompt018_004_278.txt',
#  'prompt018_005_95.txt',
#  'prompt018_006_132.txt',
#  'prompt018_007_31.txt',
#  'prompt018_008_47.txt',
#  'prompt018_009_18.txt',
#  'prompt018_010_16.txt',
#  'prompt018_011_14.txt',
#  'prompt018_012_14.txt',
#  'prompt018_013_29.txt',
#  'prompt018_014_13.txt',
#  'prompt018_015_11.txt',
#  'prompt018_016_11.txt',
#  'prompt018_017_11.txt',
#  'prompt018_018_21.txt',
#  'prompt018_019_10.txt',
#  'prompt018_020_6.txt',
#  'prompt018_021_11.txt',
#  'prompt018_022_5.txt',
#  'prompt018_023_5.txt',
#  'prompt018_024_6.txt',
#  'prompt018_025_4.txt',
#  'prompt018_026_6.txt',
#  'prompt018_027_3.txt',
#  'prompt018_028_3.txt',
#  'prompt018_029_3.txt',
#  'prompt018_030_3.txt',
#  'prompt018_031_2.txt',
#  'prompt018_032_2.txt',
#  'prompt018_033_2.txt',
#  'prompt018_034_2.txt',
#  'prompt018_035_2.txt',
#  'prompt018_036_2.txt',
#  'prompt018_037_2.txt',
#  'prompt018_038_2.txt',
#  'prompt018_039_2.txt',
#  'prompt018_040_4.txt',
#  'prompt018_041_4.txt',
#  'prompt019_000_4055.txt',
#  'prompt019_001_692.txt',
#  'prompt019_002_66.txt',
#  'prompt019_003_325.txt',
#  'prompt019_004_118.txt',
#  'prompt019_005_63.txt',
#  'prompt019_006_167.txt',
#  'prompt019_007_56.txt',
#  'prompt019_008_22.txt',
#  'prompt019_009_22.txt',
#  'prompt019_010_15.txt',
#  'prompt019_011_14.txt',
#  'prompt019_012_12.txt',
#  'prompt019_013_41.txt',
#  'prompt019_014_30.txt',
#  'prompt019_015_8.txt',
#  'prompt019_016_9.txt',
#  'prompt019_017_5.txt',
#  'prompt019_018_8.txt',
#  'prompt019_019_3.txt',
#  'prompt019_020_3.txt',
#  'prompt019_021_3.txt',
#  'prompt019_022_3.txt',
#  'prompt019_023_3.txt',
#  'prompt019_024_3.txt',
#  'prompt019_025_3.txt',
#  'prompt019_026_2.txt',
#  'prompt019_027_2.txt',
#  'prompt019_028_2.txt',
#  'prompt019_029_1.txt',
#  'prompt019_030_1.txt',
#  'prompt019_031_1.txt',
#  'prompt019_032_1.txt',
#  'prompt019_033_1.txt',
#  'prompt019_034_1.txt',
#  'prompt019_035_1.txt',
#  'prompt019_036_1.txt',
#  'prompt019_037_1.txt',
#  'prompt019_038_1.txt',
#  'prompt020_000_11056.txt',
#  'prompt020_001_1162.txt',
#  'prompt020_002_4192.txt',
#  'prompt020_003_371.txt',
#  'prompt020_004_213.txt',
#  'prompt020_005_71.txt',
#  'prompt020_006_139.txt',
#  'prompt020_007_167.txt',
#  'prompt020_008_227.txt',
#  'prompt020_009_82.txt',
#  'prompt020_010_20.txt',
#  'prompt020_011_57.txt',
#  'prompt020_012_37.txt',
#  'prompt020_013_66.txt',
#  'prompt020_014_17.txt',
#  'prompt020_015_42.txt',
#  'prompt020_016_13.txt',
#  'prompt020_017_13.txt',
#  'prompt020_018_27.txt',
#  'prompt020_019_9.txt',
#  'prompt020_020_10.txt',
#  'prompt020_021_8.txt',
#  'prompt020_022_9.txt',
#  'prompt020_023_8.txt',
#  'prompt020_024_7.txt',
#  'prompt020_025_7.txt',
#  'prompt020_026_7.txt',
#  'prompt020_027_6.txt',
#  'prompt020_028_6.txt',
#  'prompt020_029_20.txt',
#  'prompt020_030_26.txt',
#  'prompt020_031_4.txt',
#  'prompt020_032_5.txt',
#  'prompt020_033_3.txt',
#  'prompt020_034_3.txt',
#  'prompt020_035_3.txt',
#  'prompt020_036_2.txt',
#  'prompt020_037_2.txt',
#  'prompt020_038_2.txt',
#  'prompt020_039_2.txt',
#  'prompt020_040_2.txt',
#  'prompt020_041_2.txt',
#  'prompt020_042_2.txt',
#  'prompt020_043_2.txt',
#  'prompt020_044_4.txt',
#  'prompt021_000_359.txt',
#  'prompt021_001_3183.txt',
#  'prompt021_002_332.txt',
#  'prompt021_003_1770.txt',
#  'prompt021_004_50.txt',
#  'prompt021_005_97.txt',
#  'prompt021_006_53.txt',
#  'prompt021_007_26.txt',
#  'prompt021_008_22.txt',
#  'prompt021_009_45.txt',
#  'prompt021_010_14.txt',
#  'prompt021_011_12.txt',
#  'prompt021_012_11.txt',
#  'prompt021_013_12.txt',
#  'prompt021_014_8.txt',
#  'prompt021_015_5.txt',
#  'prompt021_016_6.txt',
#  'prompt021_017_4.txt',
#  'prompt021_018_3.txt',
#  'prompt021_019_4.txt',
#  'prompt021_020_4.txt',
#  'prompt021_021_4.txt',
#  'prompt021_022_4.txt',
#  'prompt021_023_5.txt',
#  'prompt021_024_5.txt',
#  'prompt021_025_3.txt',
#  'prompt021_026_3.txt',
#  'prompt021_027_3.txt',
#  'prompt021_028_3.txt',
#  'prompt021_029_3.txt',
#  'prompt021_030_3.txt',
#  'prompt021_031_3.txt',
#  'prompt021_032_3.txt',
#  'prompt021_033_3.txt',
#  'prompt021_034_3.txt',
#  'prompt021_035_3.txt',
#  'prompt021_036_2.txt',
#  'prompt021_037_1.txt',
#  'prompt021_038_1.txt',
#  'prompt021_039_1.txt',
#  'prompt021_040_1.txt',
#  'prompt022_000_9291.txt',
#  'prompt022_001_325.txt',
#  'prompt022_002_85.txt',
#  'prompt022_003_69.txt',
#  'prompt022_004_24.txt',
#  'prompt022_005_18.txt',
#  'prompt022_006_10.txt',
#  'prompt022_007_10.txt',
#  'prompt022_008_6.txt',
#  'prompt022_009_5.txt',
#  'prompt022_010_6.txt',
#  'prompt022_011_6.txt',
#  'prompt022_012_5.txt',
#  'prompt022_013_5.txt',
#  'prompt022_014_5.txt',
#  'prompt022_015_2.txt',
#  'prompt022_016_2.txt',
#  'prompt022_017_2.txt',
#  'prompt022_018_2.txt',
#  'prompt022_019_2.txt',
#  'prompt022_020_3.txt',
#  'prompt023_000_851.txt',
#  'prompt023_001_187.txt',
#  'prompt023_002_29.txt',
#  'prompt023_003_23.txt',
#  'prompt023_004_24.txt',
#  'prompt023_005_12.txt',
#  'prompt023_006_7.txt',
#  'prompt023_007_11.txt',
#  'prompt023_008_4.txt',
#  'prompt023_009_10.txt',
#  'prompt023_010_2.txt',
#  'prompt023_011_2.txt',
#  'prompt023_012_2.txt',
#  'prompt023_013_2.txt',
#  'prompt023_014_5.txt',
#  'prompt023_015_1.txt',
#  'prompt024_000_2859.txt',
#  'prompt024_001_4651.txt',
#  'prompt024_002_422.txt',
#  'prompt024_003_115.txt',
#  'prompt024_004_44.txt',
#  'prompt024_005_23.txt',
#  'prompt024_006_45.txt',
#  'prompt024_007_175.txt',
#  'prompt024_008_28.txt',
#  'prompt024_009_11.txt',
#  'prompt024_010_6.txt',
#  'prompt024_011_5.txt',
#  'prompt024_012_14.txt',
#  'prompt024_013_3.txt',
#  'prompt024_014_2.txt',
#  'prompt024_015_2.txt',
#  'prompt024_016_2.txt',
#  'prompt024_017_2.txt',
#  'prompt024_018_1.txt',
#  'prompt024_019_1.txt',
#  'prompt025_000_12528.txt',
#  'prompt025_001_2517.txt',
#  'prompt025_002_487.txt',
#  'prompt025_003_83.txt',
#  'prompt025_004_45.txt',
#  'prompt025_005_38.txt',
#  'prompt025_006_27.txt',
#  'prompt025_007_59.txt',
#  'prompt025_008_19.txt',
#  'prompt025_009_15.txt',
#  'prompt025_010_14.txt',
#  'prompt025_011_8.txt',
#  'prompt025_012_8.txt',
#  'prompt025_013_8.txt',
#  'prompt025_014_6.txt',
#  'prompt025_015_4.txt',
#  'prompt025_016_4.txt',
#  'prompt025_017_3.txt',
#  'prompt025_018_3.txt',
#  'prompt025_019_3.txt',
#  'prompt025_020_3.txt',
#  'prompt025_021_2.txt',
#  'prompt025_022_2.txt',
#  'prompt026_000_6080.txt',
#  'prompt026_001_126.txt',
#  'prompt026_002_203.txt',
#  'prompt026_003_27.txt',
#  'prompt026_004_17.txt',
#  'prompt026_005_56.txt',
#  'prompt026_006_14.txt',
#  'prompt026_007_13.txt',
#  'prompt026_008_11.txt',
#  'prompt026_009_11.txt',
#  'prompt026_010_8.txt',
#  'prompt026_011_4.txt',
#  'prompt026_012_3.txt',
#  'prompt026_013_2.txt',
#  'prompt027_000_4839.txt',
#  'prompt027_001_254.txt',
#  'prompt027_002_460.txt',
#  'prompt027_003_1618.txt',
#  'prompt027_004_79.txt',
#  'prompt027_005_321.txt',
#  'prompt027_006_55.txt',
#  'prompt027_007_88.txt',
#  'prompt027_008_90.txt',
#  'prompt027_009_28.txt',
#  'prompt027_010_29.txt',
#  'prompt027_011_46.txt',
#  'prompt027_012_21.txt',
#  'prompt027_013_16.txt',
#  'prompt027_014_14.txt',
#  'prompt027_015_10.txt',
#  'prompt027_016_10.txt',
#  'prompt027_017_9.txt',
#  'prompt027_018_6.txt',
#  'prompt027_019_7.txt',
#  'prompt027_020_7.txt',
#  'prompt027_021_6.txt',
#  'prompt027_022_7.txt',
#  'prompt027_023_6.txt',
#  'prompt027_024_5.txt',
#  'prompt027_025_4.txt',
#  'prompt027_026_5.txt',
#  'prompt027_027_4.txt',
#  'prompt027_028_3.txt',
#  'prompt027_029_3.txt',
#  'prompt027_030_3.txt',
#  'prompt027_031_2.txt',
#  'prompt027_032_2.txt',
#  'prompt027_033_2.txt',
#  'prompt027_034_2.txt',
#  'prompt027_035_2.txt',
#  'prompt027_036_2.txt',
#  'prompt027_037_2.txt',
#  'prompt027_038_2.txt',
#  'prompt027_039_2.txt',
#  'prompt027_040_2.txt',
#  'prompt027_041_2.txt',
#  'prompt028_000_2381.txt',
#  'prompt028_001_6065.txt',
#  'prompt028_002_187.txt',
#  'prompt028_003_735.txt',
#  'prompt028_004_25.txt',
#  'prompt028_005_23.txt',
#  'prompt028_006_19.txt',
#  'prompt028_007_18.txt',
#  'prompt028_008_10.txt',
#  'prompt028_009_11.txt',
#  'prompt028_010_16.txt',
#  'prompt028_011_27.txt',
#  'prompt028_012_3.txt',
#  'prompt028_013_3.txt',
#  'prompt028_014_3.txt',
#  'prompt028_015_3.txt',
#  'prompt028_016_3.txt',
#  'prompt028_017_2.txt',
#  'prompt028_018_1.txt',
#  'prompt028_019_1.txt',
#  'prompt028_020_1.txt',
#  'prompt028_021_1.txt',
#  'prompt029_000_2792.txt',
#  'prompt029_001_3113.txt',
#  'prompt029_002_2173.txt',
#  'prompt029_003_148.txt',
#  'prompt029_004_85.txt',
#  'prompt029_005_206.txt',
#  'prompt029_006_47.txt',
#  'prompt029_007_110.txt',
#  'prompt029_008_30.txt',
#  'prompt029_009_27.txt',
#  'prompt029_010_19.txt',
#  'prompt029_011_17.txt',
#  'prompt029_012_17.txt',
#  'prompt029_013_15.txt',
#  'prompt029_014_7.txt',
#  'prompt029_015_9.txt',
#  'prompt029_016_6.txt',
#  'prompt029_017_3.txt',
#  'prompt029_018_3.txt',
#  'prompt029_019_5.txt',
#  'prompt029_020_2.txt',
#  'prompt029_021_2.txt',
#  'prompt029_022_2.txt',
#  'prompt029_023_2.txt',
#  'prompt029_024_1.txt',
#  'prompt029_025_1.txt',
#  'prompt029_026_1.txt',
#  'prompt029_027_1.txt',
#  'prompt029_028_1.txt',
#  'prompt030_000_2502.txt',
#  'prompt030_001_1214.txt',
#  'prompt030_002_42.txt',
#  'prompt030_003_9.txt',
#  'prompt030_004_12.txt',
#  'prompt030_005_6.txt',
#  'prompt030_006_19.txt',
#  'prompt030_007_4.txt',
#  'prompt031_000_4058.txt',
#  'prompt031_001_244.txt',
#  'prompt031_002_350.txt',
#  'prompt031_003_314.txt',
#  'prompt031_004_33.txt',
#  'prompt031_005_12.txt',
#  'prompt031_006_23.txt',
#  'prompt031_007_5.txt',
#  'prompt031_008_5.txt',
#  'prompt031_009_16.txt',
#  'prompt031_010_3.txt',
#  'prompt031_011_3.txt',
#  'prompt031_012_3.txt',
#  'prompt031_013_3.txt',
#  'prompt031_014_2.txt',
#  'prompt031_015_1.txt',
#  'prompt031_016_1.txt',
#  'prompt031_017_1.txt',
#  'prompt031_018_1.txt',
#  'prompt031_019_1.txt',
#  'prompt032_000_12887.txt',
#  'prompt032_001_292.txt',
#  'prompt032_002_196.txt',
#  'prompt032_003_112.txt',
#  'prompt032_004_46.txt',
#  'prompt032_005_186.txt',
#  'prompt032_006_85.txt',
#  'prompt032_007_23.txt',
#  'prompt032_008_42.txt',
#  'prompt032_009_9.txt',
#  'prompt032_010_8.txt',
#  'prompt032_011_14.txt',
#  'prompt032_012_34.txt',
#  'prompt032_013_5.txt',
#  'prompt032_014_5.txt',
#  'prompt032_015_5.txt',
#  'prompt032_016_4.txt',
#  'prompt032_017_5.txt',
#  'prompt032_018_3.txt',
#  'prompt032_019_3.txt',
#  'prompt032_020_3.txt',
#  'prompt032_021_2.txt',
#  'prompt032_022_2.txt',
#  'prompt032_023_2.txt',
#  'prompt032_024_2.txt',
#  'prompt032_025_3.txt',
#  'prompt032_026_2.txt',
#  'prompt032_027_1.txt',
#  'prompt032_028_1.txt',
#  'prompt032_029_1.txt',
#  'prompt033_000_2093.txt',
#  'prompt033_001_9698.txt',
#  'prompt033_002_534.txt',
#  'prompt033_003_363.txt',
#  'prompt033_004_360.txt',
#  'prompt033_005_382.txt',
#  'prompt033_006_160.txt',
#  'prompt033_007_81.txt',
#  'prompt033_008_25.txt',
#  'prompt033_009_151.txt',
#  'prompt033_010_86.txt',
#  'prompt033_011_49.txt',
#  'prompt033_012_16.txt',
#  'prompt033_013_34.txt',
#  'prompt033_014_16.txt',
#  'prompt033_015_13.txt',
#  'prompt033_016_35.txt',
#  'prompt033_017_11.txt',
#  'prompt033_018_10.txt',
#  'prompt033_019_26.txt',
#  'prompt033_020_9.txt',
#  'prompt033_021_7.txt',
#  'prompt033_022_6.txt',
#  'prompt033_023_5.txt',
#  'prompt033_024_10.txt',
#  'prompt033_025_3.txt',
#  'prompt033_026_3.txt',
#  'prompt033_027_3.txt',
#  'prompt033_028_3.txt',
#  'prompt033_029_9.txt',
#  'prompt033_030_2.txt',
#  'prompt033_031_2.txt',
#  'prompt033_032_2.txt',
#  'prompt033_033_2.txt',
#  'prompt033_034_2.txt',
#  'prompt034_000_764.txt',
#  'prompt034_001_1369.txt',
#  'prompt034_002_145.txt',
#  'prompt034_003_383.txt',
#  'prompt034_004_142.txt',
#  'prompt034_005_51.txt',
#  'prompt034_006_38.txt',
#  'prompt034_007_18.txt',
#  'prompt034_008_14.txt',
#  'prompt034_009_15.txt',
#  'prompt034_010_94.txt',
#  'prompt034_011_23.txt',
#  'prompt034_012_9.txt',
#  'prompt034_013_7.txt',
#  'prompt034_014_5.txt',
#  'prompt034_015_4.txt',
#  'prompt034_016_5.txt',
#  'prompt034_017_2.txt',
#  'prompt034_018_2.txt',
#  'prompt034_019_2.txt',
#  'prompt034_020_2.txt',
#  'prompt034_021_1.txt',
#  'prompt034_022_1.txt',
#  'prompt034_023_1.txt',
#  'prompt034_024_1.txt',
#  'prompt035_000_7603.txt',
#  'prompt035_001_271.txt',
#  'prompt035_002_1529.txt',
#  'prompt035_003_224.txt',
#  'prompt035_004_80.txt',
#  'prompt035_005_35.txt',
#  'prompt035_006_16.txt',
#  'prompt035_007_11.txt',
#  'prompt035_008_9.txt',
#  'prompt035_009_7.txt',
#  'prompt035_010_8.txt',
#  'prompt035_011_6.txt',
#  'prompt035_012_4.txt',
#  'prompt035_013_4.txt',
#  'prompt035_014_5.txt',
#  'prompt035_015_4.txt',
#  'prompt035_016_3.txt',
#  'prompt035_017_3.txt',
#  'prompt035_018_3.txt',
#  'prompt035_019_3.txt',
#  'prompt035_020_6.txt',
#  'prompt035_021_2.txt',
#  'prompt035_022_2.txt',
#  'prompt035_023_2.txt',
#  'prompt035_024_1.txt',
#  'prompt035_025_1.txt',
#  'prompt035_026_1.txt',
#  'prompt035_027_1.txt',
#  'prompt035_028_1.txt',
#  'prompt035_029_1.txt',
#  'prompt035_030_1.txt',
#  'prompt035_031_1.txt',
#  'prompt035_032_1.txt',
#  'prompt035_033_1.txt',
#  'prompt036_000_9546.txt',
#  'prompt036_001_4942.txt',
#  'prompt036_002_1064.txt',
#  'prompt036_003_394.txt',
#  'prompt036_004_401.txt',
#  'prompt036_005_36.txt',
#  'prompt036_006_35.txt',
#  'prompt036_007_25.txt',
#  'prompt036_008_41.txt',
#  'prompt036_009_50.txt',
#  'prompt036_010_27.txt',
#  'prompt036_011_9.txt',
#  'prompt036_012_8.txt',
#  'prompt036_013_6.txt',
#  'prompt036_014_5.txt',
#  'prompt036_015_3.txt',
#  'prompt036_016_3.txt',
#  'prompt036_017_3.txt',
#  'prompt036_018_3.txt',
#  'prompt036_019_3.txt',
#  'prompt036_020_3.txt',
#  'prompt036_021_2.txt',
#  'prompt036_022_2.txt',
#  'prompt036_023_2.txt',
#  'prompt037_000_5748.txt',
#  'prompt037_001_515.txt',
#  'prompt037_002_741.txt',
#  'prompt037_003_41.txt',
#  'prompt038_000_52.txt',
#  'prompt038_001_18.txt',
#  'prompt038_002_17.txt',
#  'prompt038_003_19.txt',
#  'prompt038_004_5.txt',
#  'prompt038_005_3.txt',
#  'prompt038_006_3.txt',
#  'prompt038_007_3.txt',
#  'prompt038_008_3.txt',
#  'prompt038_009_3.txt',
#  'prompt038_010_2.txt',
#  'prompt038_011_2.txt',
#  'prompt038_012_2.txt',
#  'prompt038_013_2.txt',
#  'prompt038_014_2.txt',
#  'prompt038_015_1.txt',
#  'prompt038_016_1.txt',
#  'prompt039_000_754.txt',
#  'prompt039_001_3758.txt',
#  'prompt039_002_4912.txt',
#  'prompt039_003_83.txt',
#  'prompt039_004_250.txt',
#  'prompt039_005_1569.txt',
#  'prompt039_006_37.txt',
#  'prompt039_007_20.txt',
#  'prompt039_008_39.txt',
#  'prompt039_009_11.txt',
#  'prompt039_010_9.txt',
#  'prompt039_011_7.txt',
#  'prompt039_012_4.txt',
#  'prompt039_013_3.txt',
#  'prompt039_014_5.txt',
#  'prompt039_015_2.txt',
#  'prompt039_016_2.txt',
#  'prompt039_017_2.txt',
#  'prompt039_018_2.txt',
#  'prompt039_019_1.txt',
#  'prompt040_000_5707.txt',
#  'prompt040_001_376.txt',
#  'prompt040_002_361.txt',
#  'prompt040_003_950.txt',
#  'prompt040_004_329.txt',
#  'prompt040_005_1669.txt',
#  'prompt040_006_3850.txt',
#  'prompt040_007_99.txt',
#  'prompt040_008_549.txt',
#  'prompt040_009_84.txt',
#  'prompt040_010_55.txt',
#  'prompt040_011_51.txt',
#  'prompt040_012_49.txt',
#  'prompt040_013_89.txt',
#  'prompt040_014_37.txt',
#  'prompt040_015_54.txt',
#  'prompt040_016_29.txt',
#  'prompt040_017_25.txt',
#  'prompt040_018_23.txt',
#  'prompt040_019_21.txt',
#  'prompt040_020_19.txt',
#  'prompt040_021_39.txt',
#  'prompt040_022_17.txt',
#  'prompt040_023_15.txt',
#  'prompt040_024_14.txt',
#  'prompt040_025_12.txt',
#  'prompt040_026_9.txt',
#  'prompt040_027_11.txt',
#  'prompt040_028_6.txt',
#  'prompt040_029_6.txt',
#  'prompt040_030_22.txt',
#  'prompt040_031_4.txt',
#  'prompt040_032_6.txt',
#  'prompt040_033_5.txt',
#  'prompt040_034_5.txt',
#  'prompt040_035_5.txt',
#  'prompt040_036_5.txt',
#  'prompt040_037_3.txt',
#  'prompt040_038_3.txt',
#  'prompt040_039_3.txt',
#  'prompt040_040_3.txt',
#  'prompt040_041_2.txt',
#  'prompt040_042_2.txt',
#  'prompt040_043_2.txt',
#  'prompt041_000_7605.txt',
#  'prompt041_001_1379.txt',
#  'prompt041_002_530.txt',
#  'prompt041_003_122.txt',
#  'prompt041_004_66.txt',
#  'prompt041_005_43.txt',
#  'prompt041_006_26.txt',
#  'prompt041_007_39.txt',
#  'prompt042_000_9283.txt',
#  'prompt042_001_462.txt',
#  'prompt042_002_631.txt',
#  'prompt042_003_85.txt',
#  'prompt042_004_39.txt',
#  'prompt042_005_26.txt',
#  'prompt042_006_17.txt',
#  'prompt042_007_71.txt',
#  'prompt042_008_8.txt',
#  'prompt042_009_6.txt',
#  'prompt042_010_3.txt',
#  'prompt042_011_3.txt',
#  'prompt042_012_3.txt',
#  'prompt042_013_1.txt',
#  'prompt042_014_1.txt',
#  'prompt043_000_2500.txt',
#  'prompt043_001_2810.txt',
#  'prompt043_002_427.txt',
#  'prompt043_003_150.txt',
#  'prompt043_004_74.txt',
#  'prompt043_005_1122.txt',
#  'prompt043_006_155.txt',
#  'prompt043_007_21.txt',
#  'prompt043_008_47.txt',
#  ...]

# %%
# Tab completion
plain_corpus.fileids
# Out:
# <bound method CorpusReader.fileids of <PlaintextCorpusReader in '/mnt/c/Users/Owner/bashDir/school/text_mining/project/data/texts'>>

# %%
# More imports, in addition to those above
from   glob import glob

# We're going to read just the file names to create the category map
file_paths = glob(os.path.join(text_dir, '*.txt')) # glob lets us use wildcards in paths
file_names = [os.path.split(i)[1] for i in file_paths] # split filenames from paths

category_map = {} # Dict to hold filename:[categories] mappings

for file in file_names:
    parsed = file.rstrip('.txt').split('_') # strip extension and split on hyphens
    prompt_num = str(parsed[0][6:9])
    score = str(parsed[2])
    category_map[file] = [prompt_num, score, ' '.join([prompt_num,score])]

# %%
DOC_PATTERN = '.+\.txt'         # Documents are just files that end in '.txt'
CAT_PATTERN = r'([a-z_\s]+)/.*' # We won't use this, but fall back to directory-based labels
                                # if no other labels are supplied

import codecs
import nltk.data
from   nltk.tokenize import *
from   nltk.corpus.reader.util import *
from   nltk.corpus.reader.api import *
from   nltk.corpus.reader import PlaintextCorpusReader

class TMNCorpusReader(CategorizedCorpusReader, PlaintextCorpusReader):
    """
    A corpus reader for categorized text documents to enable preprocessing.
    """
    
    def __init__(
        self, 
        root, 
        fileids=DOC_PATTERN,
        word_tokenizer=WordPunctTokenizer(),
        sent_tokenizer=nltk.data.LazyLoader('tokenizers/punkt/english.pickle'),
        para_block_reader=read_blankline_block,
        encoding='utf8', 
        **kwargs
    ):
        """
        Initialize the corpus reader.  Categorization arguments
        (``cat_pattern``, ``cat_map``, and ``cat_file``) are passed to
        the ``CategorizedCorpusReader`` constructor.  The remaining
        arguments are passed to the ``CorpusReader`` constructor.
        """
        # Add the default category pattern if not passed into the class.
        if not any(key.startswith('cat_') for key in kwargs.keys()):
            kwargs['cat_pattern'] = CAT_PATTERN

        # Initialize the NLTK corpus reader objects
        CategorizedCorpusReader.__init__(self, kwargs)
        PlaintextCorpusReader.__init__(self, root, fileids, encoding)
        self._word_tokenizer = word_tokenizer
        self._sent_tokenizer = sent_tokenizer
        self._para_block_reader = para_block_reader

    def resolve(self, fileids, categories):
        """
        Returns a list of fileids or categories depending on what is passed
        to each internal corpus reader function. Implemented similarly to
        the NLTK ``CategorizedPlaintextCorpusReader``.
        """
        if fileids is not None and categories is not None:
            raise ValueError("Specify fileids or categories, not both")

        if categories is not None:
            return self.fileids(categories)
        return fileids

    def docs(self, fileids=None, categories=None):
        """
        Returns the complete text of a document, closing the document
        after we are done reading it and yielding it in a memory safe fashion.
        """
        # Resolve the fileids and the categories
        fileids = self.resolve(fileids, categories)

        # Create a generator, loading one document into memory at a time.
        for path, encoding in self.abspaths(fileids, include_encoding=True):
            with codecs.open(path, 'r', encoding=encoding) as f:
                yield f.read()

    def sizes(self, fileids=None, categories=None):
        """
        Returns a list of tuples, the fileid and size on disk of the file.
        This function is used to detect oddly large files in the corpus.
        """
        # Resolve the fileids and the categories
        fileids = self.resolve(fileids, categories)

        # Create a generator, getting every path and computing filesize
        for path in self.abspaths(fileids):
            yield os.path.getsize(path)
            
    # Code below this line is extra, not (yet) covered in the textbook.
    # You can leave it as-is. It provides some standard corpus methods.
    # We're using PlaintextCorpusReader methods, but providing category resolution
    def raw(self, fileids=None, categories=None):
        """
        Returns raw text as a string.
        """
        return PlaintextCorpusReader.raw(self, self.resolve(fileids, categories))

    def words(self, fileids=None, categories=None):
        """
        Returns a list of words.
        """
        return PlaintextCorpusReader.words(self, self.resolve(fileids, categories))

    def sents(self, fileids=None, categories=None):
        """
        Returns a list of tokenized sentences.
        """
        return PlaintextCorpusReader.sents(self, self.resolve(fileids, categories))

    def paras(self, fileids=None, categories=None):
        """
        Returns a list of tokenized sentences.
        """
        return PlaintextCorpusReader.paras(self, self.resolve(fileids, categories))

# %%
corpus = TMNCorpusReader(text_dir, cat_map=category_map)

print("\nThe first five fileids:\n", corpus.fileids()[:5])

print("\nTotal words in the corpus:")
print(len(corpus.words()))
# Out:
# The first five fileids:
#  ['prompt000_000_4045.txt', 'prompt000_001_9856.txt', 'prompt000_002_228.txt', 'prompt000_003_126.txt', 'prompt000_004_101.txt']
#
# Total words in the corpus:
# 14577064
